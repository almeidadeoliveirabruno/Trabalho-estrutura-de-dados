# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def criar_grafico_comparativo(x1,y1,x2,y2,titulo,intervalo_x = None, intervalo_y = None,tempo = '(S)'):    
    plt.figure(figsize=(16,9))
    plt.gca().set_facecolor('#ffffff')
    plt.gcf().set_facecolor('#be7af3')
    plt.title(titulo, font = {'size':17})
    plt.grid()
    plt.plot(x1,y1, marker='o', color='#070A40', label='Quick sort')
    plt.plot(x2,y2, marker='o', color='#69AFBF', label = 'Insertion sort')
    if intervalo_x != None:
        plt.xticks(intervalo_x)
    if intervalo_y != None:
        plt.yticks(intervalo_y)
    plt.legend()
    plt.ylabel('Tempo ' + tempo, font = {'size':14})
    plt.xlabel('Quantidade de Termos', font = {'size':14})
    nome_img = titulo + '.svg'
    plt.savefig(nome_img, format='svg')
    plt.show()

# %%
def criar_grafico_individual(x1,y1,y2,y3,titulo,intervalo_x = None, intervalo_y = None,tempo = '(S)'):    
    plt.figure(figsize=(16,4.5))
    plt.gca().set_facecolor('#ffffff')
    plt.gcf().set_facecolor('#be7af3')
    plt.title(titulo, font = {'size':17})
    plt.grid()
    plt.plot(x1,y1, marker='o', color='#070A40', label='Lista Aleatória')
    plt.plot(x1,y2, marker='o', color='#69AFBF', label = 'Lista Ordenada')
    plt.plot(x1,y3, marker='o', color='#F9DB82', label = 'Lista Ordenada Reversa')
    if intervalo_x != None:
        plt.xticks(intervalo_x)
    if intervalo_y != None:
        plt.yticks(intervalo_y)
    plt.legend()
    plt.ylabel('Tempo ' + tempo, font = {'size':14})
    plt.xlabel('Quantidade de Termos', font = {'size':14})
    nome_img = titulo + '.svg'
    plt.savefig(nome_img, format='svg')
    plt.show()

# %% [markdown]
# # Listas pequenas

# %%
tempos_pequenos_insertion = pd.read_csv('tempos_pequenas_insertion_sort.csv',encoding='utf-8')
#tempos_pequenos_insertion.to_excel('tempos_pequenas_insertion_sort.xlsx', index = False)
tempos_pequenos_insertion.head()
# Out:
#    Tamanho      Tipo de Lista  Tempo (ns)
# 0       10  Pequena Aleatoria       15600
# 1       20  Pequena Aleatoria       13000
# 2       30  Pequena Aleatoria       20500
# 3       40  Pequena Aleatoria       37000
# 4       50  Pequena Aleatoria       63000

# %%
tempos_pequenos_quicksort = pd.read_csv('tempos_pequenas_Quick_sort.csv')
#tempos_pequenos_quicksort.to_excel('tempos_pequenas_Quick_sort.xlsx', index = False)
tempos_pequenos_quicksort.head(5)
# Out:
#    Tamanho      Tipo de Lista  Tempo (ns)
# 0       10  Pequena Aleatoria       59100
# 1       20  Pequena Aleatoria       48100
# 2       30  Pequena Aleatoria       48100
# 3       40  Pequena Aleatoria       92700
# 4       50  Pequena Aleatoria      137200

# %% [markdown]
# ## Lista Pequena aleatoria

# %%
insertion_lista_pequena_aleatoria = tempos_pequenos_insertion.iloc[0:10,:]
insertion_lista_pequena_aleatoria.head(11)
# Out:
#    Tamanho      Tipo de Lista  Tempo (ns)
# 0       10  Pequena Aleatoria       15600
# 1       20  Pequena Aleatoria       13000
# 2       30  Pequena Aleatoria       20500
# 3       40  Pequena Aleatoria       37000
# 4       50  Pequena Aleatoria       63000
# 5       60  Pequena Aleatoria       70500
# 6       70  Pequena Aleatoria      107400
# 7       80  Pequena Aleatoria      132500
# 8       90   Pequena Aleatoia      179100
# 9      100  Pequena Aleatoria      191100

# %%
quicksort_lista_pequena_aleatoria =  tempos_pequenos_quicksort.iloc[0:10,:]
quicksort_lista_pequena_aleatoria.head(11)
# Out:
#    Tamanho      Tipo de Lista  Tempo (ns)
# 0       10  Pequena Aleatoria       59100
# 1       20  Pequena Aleatoria       48100
# 2       30  Pequena Aleatoria       48100
# 3       40  Pequena Aleatoria       92700
# 4       50  Pequena Aleatoria      137200
# 5       60  Pequena Aleatoria      207400
# 6       70  Pequena Aleatoria      184400
# 7       80  Pequena Aleatoria      246000
# 8       90  Pequena Aleatoria      283000
# 9      100  Pequena Aleatoria      304800

# %%
x1 = quicksort_lista_pequena_aleatoria['Tamanho'].values
y1 = quicksort_lista_pequena_aleatoria['Tempo (ns)'].values
x2 = insertion_lista_pequena_aleatoria['Tamanho'].values
y2 = insertion_lista_pequena_aleatoria['Tempo (ns)'].values
intervalo_x = range(10,101,10)
criar_grafico_comparativo(x1,y1,x2,y2,'Lista Pequena Aleatória',intervalo_x,tempo='(NS)')

# %% [markdown]
# ## Lista Pequena ordenada

# %%
quicksort_lista_pequena_ordenada =  tempos_pequenos_quicksort.iloc[10:20,:]
quicksort_lista_pequena_ordenada.head(11)
# Out:
#     Tamanho     Tipo de Lista  Tempo (ns)
# 10       10  Pequena Ordenada       19600
# 11       20  Pequena Ordenada       38800
# 12       30  Pequena Ordenada       54300
# 13       40  Pequena Ordenada       76000
# 14       50  Pequena Ordenada      105900
# 15       60  Pequena Ordenada      120600
# 16       70  Pequena Ordenada      155800
# 17       80  Pequena Ordenada      182900
# 18       90  Pequena Ordenada      170000
# 19      100  Pequena Ordenada      160200

# %%
insertion_lista_pequena_ordenada = tempos_pequenos_insertion.iloc[10:20,:]
insertion_lista_pequena_ordenada.head(11)
# Out:
#     Tamanho     Tipo de Lista  Tempo (ns)
# 10       10  Pequena Ordenada        1900
# 11       20  Pequena Ordenada        2700
# 12       30  Pequena Ordenada        3600
# 13       40  Pequena Ordenada        4500
# 14       50  Pequena Ordenada        5500
# 15       60  Pequena Ordenada        6500
# 16       70  Pequena Ordenada        7600
# 17       80  Pequena Ordenada        8800
# 18       90  Pequena Ordenada        9700
# 19      100  Pequena Ordenada       11000

# %%
x1 = quicksort_lista_pequena_ordenada['Tamanho'].values
y1 = quicksort_lista_pequena_ordenada['Tempo (ns)'].values
x2 = insertion_lista_pequena_ordenada['Tamanho'].values
y2 = insertion_lista_pequena_ordenada['Tempo (ns)'].values
intervalo_x = range(10,101,10)
criar_grafico_comparativo(x1,y1,x2,y2,'Lista Pequena Ordenada',intervalo_x, tempo='(NS)')

# %% [markdown]
# ## Lista pequena ordenada reversa

# %%
quicksort_lista_pequena_ordenada_reversa =  tempos_pequenos_quicksort.iloc[20:30,:]
quicksort_lista_pequena_ordenada_reversa.head(11)
# Out:
#     Tamanho             Tipo de Lista  Tempo (ns)
# 20       10  Pequena Ordenada Reversa       21000
# 21       20  Pequena Ordenada Reversa       26300
# 22       30  Pequena Ordenada Reversa       33700
# 23       40  Pequena Ordenada Reversa       50800
# 24       50  Pequena Ordenada Reversa       67400
# 25       60  Pequena Ordenada Reversa       73500
# 26       70  Pequena Ordenada Reversa       90300
# 27       80  Pequena Ordenada Reversa      108600
# 28       90  Pequena Ordenada Reversa      133000
# 29      100  Pequena Ordenada Reversa      143700

# %%
insertion_lista_pequena_ordenada_reversa =  tempos_pequenos_insertion.iloc[20:30,:]
insertion_lista_pequena_ordenada_reversa.head(11)
# Out:
#     Tamanho             Tipo de Lista  Tempo (ns)
# 20       10  Pequena Ordenada Reversa        5300
# 21       20  Pequena Ordenada Reversa       18300
# 22       30  Pequena Ordenada Reversa       39600
# 23       40  Pequena Ordenada Reversa       69300
# 24       50  Pequena Ordenada Reversa      106900
# 25       60  Pequena Ordenada Reversa      153100
# 26       70  Pequena Ordenada Reversa      206900
# 27       80  Pequena Ordenada Reversa      269300
# 28       90  Pequena Ordenada Reversa      340400
# 29      100  Pequena Ordenada Reversa      419100

# %%
x1 = quicksort_lista_pequena_ordenada_reversa['Tamanho'].values
y1 = quicksort_lista_pequena_ordenada_reversa['Tempo (ns)'].values
x2 = insertion_lista_pequena_ordenada_reversa['Tamanho'].values
y2 = insertion_lista_pequena_ordenada_reversa['Tempo (ns)'].values
intervalo_x = range(10,101,10)
intervalo_y = range(0,410000,40000)
criar_grafico_comparativo(x1,y1,x2,y2,'Lista Pequena Ordenada Reversa',intervalo_x, tempo='(NS)', intervalo_y= intervalo_y)

# %% [markdown]
# ### Comparativo individual listas pequenas

# %%
x1 = quicksort_lista_pequena_aleatoria['Tamanho'].values
y1 = quicksort_lista_pequena_aleatoria['Tempo (ns)'].values
y2 = quicksort_lista_pequena_ordenada['Tempo (ns)'].values
y3 = quicksort_lista_pequena_ordenada_reversa['Tempo (ns)'].values
intervalo_x = range(10,101,10)
intervalo_y = range(0,320000,30000)
tempo = '(NS)'

criar_grafico_individual(x1,y1,y2,y3, 'Listas Pequenas Quicksort', intervalo_x = intervalo_x, intervalo_y = intervalo_y, tempo = tempo)

# %%
x1 = insertion_lista_pequena_aleatoria['Tamanho'].values
y1 = insertion_lista_pequena_aleatoria['Tempo (ns)'].values
y2 = insertion_lista_pequena_ordenada['Tempo (ns)'].values
y3 = insertion_lista_pequena_ordenada_reversa['Tempo (ns)'].values
intervalo_x = range(10,101,10)
intervalo_y = range(0,440000,30000)
tempo = '(NS)'

criar_grafico_individual(x1,y1,y2,y3, 'Listas Pequenas Insertion sort', intervalo_x = intervalo_x, intervalo_y = intervalo_y, tempo = tempo)

# %% [markdown]
# # Tempos médios

# %% [markdown]
# ### Lendo os arquivos csv dos tempos médios

# %%
tempos_medios_quick_sort = pd.read_csv('tempos_medias_Quick_sort.csv', encoding='utf-8')
#tempos_medios_quick_sort.to_excel('tempos_medias_Quick_sort.xlsx', index=False)
tempos_medios_quick_sort.head(30)
# Out:
#     Tamanho           Tipo de Lista         Tempo
# 0       950         Media Aleatoria  2.006292e-03
# 1      1400         Media Aleatoria  5.039930e-03
# 2      1850         Media Aleatoria  7.525682e-03
# 3      2300         Media Aleatoria  6.542921e-03
# 4      2750         Media Aleatoria  9.285927e-03
# 5      3200         Media Aleatoria  8.091450e-03
# 6      3650         Media Aleatoria  1.049995e-02
# 7      4100         Media Aleatoria  1.211619e-02
# 8      4550         Media Aleatoria  1.318097e-02
# 9      5000         Media Aleatoria  1.410484e-02
# 10      950          Media Ordenada  1.517600e+06
# 11     1400          Media Ordenada  2.569300e+06
# 12     1850          Media Ordenada  3.391000e+06
# 13     2300          Media Ordenada  4.084200e+06
# 14     2750          Media Ordenada  5.193200e+06
# 15     3200          Media Ordenada  6.278200e+06
# 16     3650          Media Ordenada  6.637100e+06
# 17     4100          Media Ordenada  6.315200e+06
# ...

# %%
tempos_medios_insertion_sort = pd.read_csv('tempos_medias_insertion_sort.csv')
#tempos_medios_insertion_sort.to_excel('tempos_medias_insertion_sort.xlsx',index=False)
tempos_medios_insertion_sort.head(30)
# Out:
#     Tamanho           Tipo de Lista          Tempo
# 0       950         Media Aleatoria       0.024789
# 1      1400         Media Aleatoria       0.050143
# 2      1850         Media Aleatoria       0.124883
# 3      2300         Media Aleatoria       0.157458
# 4      2750         Media Aleatoria       0.206475
# 5      3200         Media Aleatoria       0.289374
# 6      3650         Media Aleatoria       0.357631
# 7      4100         Media Aleatoria       0.444959
# 8      4550         Media Aleatoria       0.549075
# 9      5000         Media Aleatoria       0.695050
# 10      950          Media Ordenada  150700.000000
# 11     1400          Media Ordenada  189200.000000
# 12     1850          Media Ordenada  256100.000000
# 13     2300          Media Ordenada  315600.000000
# 14     2750          Media Ordenada  380100.000000
# 15     3200          Media Ordenada  435100.000000
# 16     3650          Media Ordenada  504800.000000
# ...

# %% [markdown]
# ### Criando os graficos da lista média aleatoria

# %%
quicksort_lista_media_aleatoria = tempos_medios_quick_sort.iloc[0:10]
quicksort_lista_media_aleatoria.head(11)
# Out:
#    Tamanho    Tipo de Lista     Tempo
# 0      950  Media Aleatoria  0.002006
# 1     1400  Media Aleatoria  0.005040
# 2     1850  Media Aleatoria  0.007526
# 3     2300  Media Aleatoria  0.006543
# 4     2750  Media Aleatoria  0.009286
# 5     3200  Media Aleatoria  0.008091
# 6     3650  Media Aleatoria  0.010500
# 7     4100  Media Aleatoria  0.012116
# 8     4550  Media Aleatoria  0.013181
# 9     5000  Media Aleatoria  0.014105

# %%
insertion_lista_media_aleatoria = tempos_medios_insertion_sort[0:10]
insertion_lista_media_aleatoria.head(20)
# Out:
#    Tamanho    Tipo de Lista     Tempo
# 0      950  Media Aleatoria  0.024789
# 1     1400  Media Aleatoria  0.050143
# 2     1850  Media Aleatoria  0.124883
# 3     2300  Media Aleatoria  0.157458
# 4     2750  Media Aleatoria  0.206475
# 5     3200  Media Aleatoria  0.289374
# 6     3650  Media Aleatoria  0.357631
# 7     4100  Media Aleatoria  0.444959
# 8     4550  Media Aleatoria  0.549075
# 9     5000  Media Aleatoria  0.695050

# %%
x1 = quicksort_lista_media_aleatoria['Tamanho'].values
y1 = quicksort_lista_media_aleatoria['Tempo'].values
x2 = insertion_lista_media_aleatoria['Tamanho'].values
y2 = insertion_lista_media_aleatoria['Tempo'].values
intervalo_x = range(950,5001,450)

criar_grafico_comparativo(x1,y1,x2,y2,'Lista Média Aleatoria',intervalo_x)

# %% [markdown]
# ### listas médias ordenadas
# O tempo estava em nanossegundos, precisando de ser alterado. <br>
# Foi corrigdo o erro no

# %%
quicksort_lista_media_ordenada = tempos_medios_quick_sort.iloc[10:20]
quicksort_lista_media_ordenada['Tempo'] = quicksort_lista_media_ordenada['Tempo'].values / 1000000
quicksort_lista_media_ordenada.head(11)
# Out:
# C:\Users\bruno\AppData\Local\Temp\ipykernel_1492\674728859.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quicksort_lista_media_ordenada['Tempo'] = quicksort_lista_media_ordenada['Tempo'].values / 1000000
#     Tamanho   Tipo de Lista   Tempo
# 10      950  Media Ordenada  1.5176
# 11     1400  Media Ordenada  2.5693
# 12     1850  Media Ordenada  3.3910
# 13     2300  Media Ordenada  4.0842
# 14     2750  Media Ordenada  5.1932
# 15     3200  Media Ordenada  6.2782
# 16     3650  Media Ordenada  6.6371
# 17     4100  Media Ordenada  6.3152
# 18     4550  Media Ordenada  7.5396
# 19     5000  Media Ordenada  8.3019

# %%
insertion_lista_media_ordenada = tempos_medios_insertion_sort.iloc[10:20]
insertion_lista_media_ordenada['Tempo'] = insertion_lista_media_ordenada['Tempo'].values / 1000000
insertion_lista_media_ordenada.head(11)
# Out:
# C:\Users\bruno\AppData\Local\Temp\ipykernel_1492\253953100.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insertion_lista_media_ordenada['Tempo'] = insertion_lista_media_ordenada['Tempo'].values / 1000000
#     Tamanho   Tipo de Lista   Tempo
# 10      950  Media Ordenada  0.1507
# 11     1400  Media Ordenada  0.1892
# 12     1850  Media Ordenada  0.2561
# 13     2300  Media Ordenada  0.3156
# 14     2750  Media Ordenada  0.3801
# 15     3200  Media Ordenada  0.4351
# 16     3650  Media Ordenada  0.5048
# 17     4100  Media Ordenada  0.5613
# 18     4550  Media Ordenada  0.6293
# 19     5000  Media Ordenada  0.7172

# %%
x1 = quicksort_lista_media_ordenada['Tamanho'].values
y1 = quicksort_lista_media_ordenada['Tempo'].values
x2 = insertion_lista_media_ordenada['Tamanho'].values
y2 = insertion_lista_media_ordenada['Tempo'].values
intervalo_x = range(950,5001,450)
tempo = '(MS)'
criar_grafico_comparativo(x1,y1,x2,y2,'Lista Média Ordenada',intervalo_x = intervalo_x,  tempo = tempo)

# %% [markdown]
# ### Lista Media Ordenada Reversa

# %%
quicksort_lista_media_ordenada_reversa = tempos_medios_quick_sort.iloc[20:30]
quicksort_lista_media_ordenada_reversa.head(11)
# Out:
#     Tamanho           Tipo de Lista     Tempo
# 20      950  Media Ordenada Reversa  0.001002
# 21     1400  Media Ordenada Reversa  0.002970
# 22     1850  Media Ordenada Reversa  0.002586
# 23     2300  Media Ordenada Reversa  0.003000
# 24     2750  Media Ordenada Reversa  0.005053
# 25     3200  Media Ordenada Reversa  0.005233
# 26     3650  Media Ordenada Reversa  0.005558
# 27     4100  Media Ordenada Reversa  0.006030
# 28     4550  Media Ordenada Reversa  0.008303
# 29     5000  Media Ordenada Reversa  0.008133

# %%
insertion_lista_media_ordenada_reversa = tempos_medios_insertion_sort.iloc[20:30]
insertion_lista_media_ordenada_reversa.head(11)
# Out:
#     Tamanho           Tipo de Lista     Tempo
# 20      950  Media Ordenada Reversa  0.043998
# 21     1400  Media Ordenada Reversa  0.100074
# 22     1850  Media Ordenada Reversa  0.180986
# 23     2300  Media Ordenada Reversa  0.278863
# 24     2750  Media Ordenada Reversa  0.392764
# 25     3200  Media Ordenada Reversa  0.525703
# 26     3650  Media Ordenada Reversa  0.727294
# 27     4100  Media Ordenada Reversa  0.871252
# 28     4550  Media Ordenada Reversa  1.444023
# 29     5000  Media Ordenada Reversa  2.046268

# %%
x1 = quicksort_lista_media_ordenada_reversa['Tamanho'].values
y1 = quicksort_lista_media_ordenada_reversa['Tempo'].values
x2 = insertion_lista_media_ordenada_reversa['Tamanho'].values
y2 = insertion_lista_media_ordenada_reversa['Tempo'].values
intervalo_x = range(950,5001,450)
criar_grafico_comparativo(x1,y1,x2,y2,'Lista Média Ordenada Reversa',intervalo_x)

# %% [markdown]
# ### Desempenho individual

# %%
# Transforma de novo em segundos os ms
insertion_lista_media_ordenada['Tempo'] = insertion_lista_media_ordenada['Tempo'].values / 1000
quicksort_lista_media_ordenada['Tempo'] = quicksort_lista_media_ordenada['Tempo'].values / 1000
# Out:
# C:\Users\bruno\AppData\Local\Temp\ipykernel_1492\928678672.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insertion_lista_media_ordenada['Tempo'] = insertion_lista_media_ordenada['Tempo'].values / 1000
# C:\Users\bruno\AppData\Local\Temp\ipykernel_1492\928678672.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quicksort_lista_media_ordenada['Tempo'] = quicksort_lista_media_ordenada['Tempo'].values / 1000

# %%
x1 = insertion_lista_media_aleatoria['Tamanho'].values
y1 = insertion_lista_media_aleatoria['Tempo'].values
y2 = insertion_lista_media_ordenada['Tempo'].values
y3 = insertion_lista_media_ordenada_reversa['Tempo'].values
intervalo_x = range(950,5001,450)
intervalo_y = [x/2 for x in range(0,5,1)]
print(intervalo_x)

criar_grafico_individual(x1,y1,y2,y3, 'Listas Média Insertion', intervalo_x = intervalo_x, intervalo_y = intervalo_y)
# Out:
# range(950, 5001, 450)

# %%
x1 = quicksort_lista_media_aleatoria['Tamanho'].values
y1 = quicksort_lista_media_aleatoria['Tempo'].values
y2 = quicksort_lista_media_ordenada['Tempo'].values
y3 = quicksort_lista_media_ordenada_reversa['Tempo'].values
intervalo_x = range(950,5001,450)
intervalo_y = [x/1000 for x in range(0,16,1)]
print(intervalo_x)

criar_grafico_individual(x1,y1,y2,y3, 'Listas Média Quicksort', intervalo_x = intervalo_x, intervalo_y = intervalo_y)
# Out:
# range(950, 5001, 450)

# %% [markdown]
# ## Listas Grandes

# %%
tempos_grandes_quick_sort = pd.read_csv('tempos_grandes_Quick_sort.csv')
#tempos_grandes_quick_sort.to_excel('tempos_grandes_Quick_sort.xlsx', index=False)
tempos_grandes_quick_sort.head(30)
# Out:
#     Tamanho            Tipo de Lista     Tempo
# 0     10000         Grande Aleatoria  0.028579
# 1     20000         Grande Aleatoria  0.059062
# 2     30000         Grande Aleatoria  0.090410
# 3     40000         Grande Aleatoria  0.125157
# 4     50000         Grande Aleatoria  0.155709
# 5     60000         Grande Aleatoria  0.197054
# 6     70000         Grande Aleatoria  0.214945
# 7     80000         Grande Aleatoria  0.237676
# 8     90000         Grande Aleatoria  0.300369
# 9    100000         Grande Aleatoria  0.303044
# 10    10000          Grande Ordenada  0.018967
# 11    20000          Grande Ordenada  0.039331
# 12    30000          Grande Ordenada  0.059481
# 13    40000          Grande Ordenada  0.083812
# 14    50000          Grande Ordenada  0.104977
# 15    60000          Grande Ordenada  0.125292
# 16    70000          Grande Ordenada  0.148798
# 17    80000          Grande Ordenada  0.176327
# 18    90000          Grande Ordenada  0.210815
# ...

# %%
tempos_grandes_insertion = pd.read_csv('tempos_grandes_insertion_sort.csv')
#tempos_grandes_insertion.to_excel('tempos_grandes_insertion_sort.xlsx', index= False)
tempos_grandes_insertion.head(30)
# Out:
#     Tamanho            Tipo de Lista       Tempo
# 0     10000         Grande Aleatoria    2.848603
# 1     20000         Grande Aleatoria   10.953386
# 2     30000         Grande Aleatoria   25.332814
# 3     40000         Grande Aleatoria   46.242143
# 4     50000         Grande Aleatoria   74.216041
# 5     60000         Grande Aleatoria  102.289072
# 6     70000         Grande Aleatoria  145.276599
# 7     80000         Grande Aleatoria  229.662847
# 8     90000         Grande Aleatoria  252.033324
# 9    100000         Grande Aleatoria  293.030275
# 10    10000          Grande Ordenada    0.001001
# 11    20000          Grande Ordenada    0.003001
# 12    30000          Grande Ordenada    0.004615
# 13    40000          Grande Ordenada    0.006001
# 14    50000          Grande Ordenada    0.008359
# 15    60000          Grande Ordenada    0.009575
# 16    70000          Grande Ordenada    0.012445
# 17    80000          Grande Ordenada    0.014932
# ...

# %% [markdown]
# ### Lista grande aleatoria

# %%
quicksort_lista_grande_aleatoria = tempos_grandes_quick_sort.iloc[0:10,:]
quicksort_lista_grande_aleatoria.head(11)
# Out:
#    Tamanho     Tipo de Lista     Tempo
# 0    10000  Grande Aleatoria  0.028579
# 1    20000  Grande Aleatoria  0.059062
# 2    30000  Grande Aleatoria  0.090410
# 3    40000  Grande Aleatoria  0.125157
# 4    50000  Grande Aleatoria  0.155709
# 5    60000  Grande Aleatoria  0.197054
# 6    70000  Grande Aleatoria  0.214945
# 7    80000  Grande Aleatoria  0.237676
# 8    90000  Grande Aleatoria  0.300369
# 9   100000  Grande Aleatoria  0.303044

# %%
insertion_lista_grande_aleatoria = tempos_grandes_insertion.iloc[0:10,:]
insertion_lista_grande_aleatoria.head(10)
# Out:
#    Tamanho     Tipo de Lista       Tempo
# 0    10000  Grande Aleatoria    2.848603
# 1    20000  Grande Aleatoria   10.953386
# 2    30000  Grande Aleatoria   25.332814
# 3    40000  Grande Aleatoria   46.242143
# 4    50000  Grande Aleatoria   74.216041
# 5    60000  Grande Aleatoria  102.289072
# 6    70000  Grande Aleatoria  145.276599
# 7    80000  Grande Aleatoria  229.662847
# 8    90000  Grande Aleatoria  252.033324
# 9   100000  Grande Aleatoria  293.030275

# %%
x1 = quicksort_lista_grande_aleatoria['Tamanho'].values
y1 = quicksort_lista_grande_aleatoria['Tempo'].values
x2 = insertion_lista_grande_aleatoria['Tamanho'].values
y2 = insertion_lista_grande_aleatoria['Tempo'].values
intervalo_x = range(0,100001,10000)
criar_grafico_comparativo(x1,y1,x2,y2,'Lista Grande Aleatória',intervalo_x)

# %% [markdown]
# ### Lista grande ordenada

# %%
quicksort_lista_grande_ordenada = tempos_grandes_quick_sort.iloc[10:20,:]
quicksort_lista_grande_ordenada['Tempo'] = quicksort_lista_grande_ordenada['Tempo'] * 1000
quicksort_lista_grande_ordenada.head(11)
# Out:
# C:\Users\bruno\AppData\Local\Temp\ipykernel_1492\2560636589.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quicksort_lista_grande_ordenada['Tempo'] = quicksort_lista_grande_ordenada['Tempo'] * 1000
#     Tamanho    Tipo de Lista       Tempo
# 10    10000  Grande Ordenada   18.967390
# 11    20000  Grande Ordenada   39.330721
# 12    30000  Grande Ordenada   59.481144
# 13    40000  Grande Ordenada   83.812475
# 14    50000  Grande Ordenada  104.977369
# 15    60000  Grande Ordenada  125.292301
# 16    70000  Grande Ordenada  148.798227
# 17    80000  Grande Ordenada  176.326513
# 18    90000  Grande Ordenada  210.814953
# 19   100000  Grande Ordenada  236.801147

# %%
insertion_lista_grande_ordenada = tempos_grandes_insertion.iloc[10:20,:]
insertion_lista_grande_ordenada['Tempo'] = insertion_lista_grande_ordenada['Tempo'] * 1000
insertion_lista_grande_ordenada.head(30)
# Out:
# C:\Users\bruno\AppData\Local\Temp\ipykernel_1492\2360814876.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insertion_lista_grande_ordenada['Tempo'] = insertion_lista_grande_ordenada['Tempo'] * 1000
#     Tamanho    Tipo de Lista      Tempo
# 10    10000  Grande Ordenada   1.000881
# 11    20000  Grande Ordenada   3.000736
# 12    30000  Grande Ordenada   4.614592
# 13    40000  Grande Ordenada   6.001234
# 14    50000  Grande Ordenada   8.358955
# 15    60000  Grande Ordenada   9.574890
# 16    70000  Grande Ordenada  12.444735
# 17    80000  Grande Ordenada  14.931679
# 18    90000  Grande Ordenada  16.591549
# 19   100000  Grande Ordenada  18.044233

# %%
x1 = quicksort_lista_grande_ordenada['Tamanho'].values
y1 = quicksort_lista_grande_ordenada['Tempo'].values
x2 = insertion_lista_grande_ordenada['Tamanho'].values
y2 = insertion_lista_grande_ordenada['Tempo'].values
intervalo_x = range(0,100001,10000)
intervalo_y = range(0,260,20)
tempo = '(MS)'
criar_grafico_comparativo(x1,y1,x2,y2,'Lista Grande Ordenada',intervalo_x,intervalo_y, tempo = tempo)

# %% [markdown]
# ### Lista grande ordenada reversa

# %%
quicksort_lista_grande_ordenada_reversa = tempos_grandes_quick_sort.iloc[20:30]
quicksort_lista_grande_ordenada_reversa.head(11)
# Out:
#     Tamanho            Tipo de Lista     Tempo
# 20    10000  Grande Ordenada Reversa  0.019366
# 21    20000  Grande Ordenada Reversa  0.040923
# 22    30000  Grande Ordenada Reversa  0.063845
# 23    40000  Grande Ordenada Reversa  0.087370
# 24    50000  Grande Ordenada Reversa  0.113633
# 25    60000  Grande Ordenada Reversa  0.129078
# 26    70000  Grande Ordenada Reversa  0.149020
# 27    80000  Grande Ordenada Reversa  0.188976
# 28    90000  Grande Ordenada Reversa  0.216027
# 29   100000  Grande Ordenada Reversa  0.217232

# %%
insertion_lista_grande_ordenada_reversa = tempos_grandes_insertion.iloc[20:30,:]
insertion_lista_grande_ordenada_reversa.head(11)
# Out:
#     Tamanho            Tipo de Lista       Tempo
# 20    10000  Grande Ordenada Reversa    4.355407
# 21    20000  Grande Ordenada Reversa   20.580704
# 22    30000  Grande Ordenada Reversa   50.194352
# 23    40000  Grande Ordenada Reversa   88.538902
# 24    50000  Grande Ordenada Reversa  153.470047
# 25    60000  Grande Ordenada Reversa  215.082543
# 26    70000  Grande Ordenada Reversa  327.037404
# 27    80000  Grande Ordenada Reversa  463.595852
# 28    90000  Grande Ordenada Reversa  546.159898
# 29   100000  Grande Ordenada Reversa  702.700120

# %%
x1 = quicksort_lista_grande_ordenada_reversa['Tamanho'].values
y1 = quicksort_lista_grande_ordenada_reversa['Tempo'].values
x2 = insertion_lista_grande_ordenada_reversa['Tamanho'].values
y2 = insertion_lista_grande_ordenada_reversa['Tempo'].values
intervalo_x = range(0,100001,10000)
#intervalo_y = range(0,260,20)
criar_grafico_comparativo(x1,y1,x2,y2, 'Lista Grande Ordenada Reversa', intervalo_x= intervalo_x)

# %% [markdown]
# ### Comparativo listas grandes

# %%
#Transformar a listra grande ordenada em segundos novamente
insertion_lista_grande_ordenada['Tempo'] = insertion_lista_grande_ordenada['Tempo'] / 1000
quicksort_lista_grande_ordenada['Tempo'] = quicksort_lista_grande_ordenada['Tempo'] / 1000
# Out:
# C:\Users\bruno\AppData\Local\Temp\ipykernel_1492\3747077727.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insertion_lista_grande_ordenada['Tempo'] = insertion_lista_grande_ordenada['Tempo'] / 1000
# C:\Users\bruno\AppData\Local\Temp\ipykernel_1492\3747077727.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quicksort_lista_grande_ordenada['Tempo'] = quicksort_lista_grande_ordenada['Tempo'] / 1000

# %%
x1 = insertion_lista_grande_aleatoria['Tamanho'].values
y1 = insertion_lista_grande_aleatoria['Tempo'].values
y2 = insertion_lista_grande_ordenada['Tempo'].values
y3 = insertion_lista_grande_ordenada_reversa['Tempo'].values
intervalo_x = range(10000,440,100000)
intervalo_y = range(0,750,50)
print(intervalo_x)

criar_grafico_individual(x1,y1,y2,y3, 'Listas Grandes Insertion', intervalo_x = intervalo_x, intervalo_y = intervalo_y)
# Out:
# range(10000, 440, 100000)

# %%
x1 = quicksort_lista_grande_aleatoria['Tamanho'].values
y1 = quicksort_lista_grande_aleatoria['Tempo'].values
y2 = quicksort_lista_grande_ordenada['Tempo'].values
y3 = quicksort_lista_grande_ordenada_reversa['Tempo'].values
intervalo_x = range(10000,440,100000)
intervalo_y = [x / 100 for x in range(0,33,2)]
criar_grafico_individual(x1,y1,y2,y3, 'Listas Grandes Quicksort', intervalo_x = intervalo_x, intervalo_y= intervalo_y)
